# %%
# %matplotlib widget
# aka import ipympl

import matplotlib.pyplot as plt
from sdot import PowerDiagram
import numpy as np

pd = PowerDiagram( positions = np.random.random( [ 10, 2 ] ) )
pd.plot_in_pyplot( plt )
plt.show()

# %%
print( pd.measures() )
