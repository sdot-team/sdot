# %%
from sdot import optimal_transport_plan
import numpy as np

# pd = PowerDiagram( positions = np.random.random( [ 40, 2 ] ) )
# pd.plot()

ot = optimal_transport_plan( np.random.random( [ 40, 2 ] ) )
ot.plot()
# Out:
# max_error_ratio: 2.8486e+00 (first iteration)
# max_error_ratio: 3.5550e-01 nb_relaxation_steps: 0
# max_error_ratio: 1.4653e-02 nb_relaxation_steps: 0
# max_error_ratio: 5.0029e-05 nb_relaxation_steps: 0

# %%
np.eye( 2 )
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
import matplotlib.pyplot as plt
from sdot import Cell

cell = Cell( ndim = 3 )

# we create a triangle, infinitely extruded
cell.cut( [ -1,  0, 0 ], 0 )
cell.cut( [  0, -1, 0 ], 0 )
cell.cut( [ +1, +1, 0 ], 1 )

# naturally, there's no 3D vertex...
print( cell.nb_vertices ) # => 0

# and this cell is sill unbounded (in 3D)
print( cell.bounded ) # => False

# It's because we're in 2D
print( cell.true_dimensionality ) # => 2

# "td" is the shortcut for "true dimensionality".
# Method with with prefix return the information for the subspace defined by `cell.base`
print( cell.nb_vertices_td ) # => 3 (the 3 vertices of the triangle)

# we can get coordinates to represent these points in 3D
print( cell.vertex_coords_td @ cell.base ) # => [[0. 0. 0.] [1. 0. 0.] [0. 1. 0.]]

cell.plot( plt )
plt.show()
# Out:
# sdot_bindings_for_3_FP64_Linux_skylake_avx512 dict_keys([])
# 0
# False
# 2
# 3
# [[0. 0. 0.]
#  [1. 0. 0.]
#  [0. 1. 0.]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 27
#      24 # we can get coordinates to represent these points in 3D
#      25 print( cell.vertex_coords_td @ cell.base ) # => [[0. 0. 0.] [1. 0. 0.] [0. 1. 0.]]
# ---> 27 cell.plot( plt )
#      28 plt.show()
#
# File ~/micromamba/envs/sdot/lib/python3.13/site-packages/sdot/Cell.py:158, in Cell.plot(self, fig, color, linestyle, ray_length, ray_color, ray_linestyle)
#     155     if len( ray_refs ) >= 2:
#     156         disp_ray( ray_refs[ 1 ], vertex_indices[ -1 ], 0 )
# --> 158 self.for_each_face( on_face )
#     159 fig.axis('equal')
#     160 return
#
# File ~/micromamba/envs/sdot/lib/python3.13/site-packages/sdot/Cell.py:120, in Cell.for_each_face(self, on_face)
#     115 def for_each_face( self, on_face ):
#     116     """
#     117         Call args:
#     118             on_face( cut_refs, vertex_indices, ray_refs_list ),
#     119     """
# --> 120     return self._cell.for_each_face( on_face )
#
# AttributeError: 'sdot_bindings_for_3_FP64_Linux_skylake_avx512.Cell_3_FP64_Linux_skylake_avx512' object has no attribute 'for_each_face'

# %%
import matplotlib.pyplot as plt
from sdot import PowerDiagram
import numpy as np

pd = PowerDiagram( positions = np.random.random( [ 30, 2 ] ) )

pd.periodicity_transformations = [
    ( np.eye( 2 ), [ 0, 1 ] )
]
print( np.ptp( pd.summary().vertex_coords[ :, 0 ] ) )
pd.plot()
# Out:
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       5 pd = PowerDiagram( positions = np.random.random( [ 30, 2 ] ) )
#       7 pd.periodicity_transformations = [
#       8     ( np.eye( 2 ), [ 0, 1 ] )
#       9 ]
# ---> 10 print( np.ptp( pd.summary().vertex_coords[ :, 0 ] ) )
#      11 pd.plot()
#
# TypeError: list indices must be integers or slices, not tuple
